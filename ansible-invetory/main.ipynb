# %%
import nmap
import paramiko
import openpyxl
import socket
import re
import ipaddress

# %%
import paramiko
import openpyxl
import socket
import re
import ipaddress
import subprocess
import os

# Define your sudo password in a file in the same directory called sudopass
SUDO_PASSWORD = "password"
timeout = "1s"
with open(f'{os.getcwd()}/sudopass') as f: 
    SUDO_PASSWORD = f.read()

with open('sudopass') as f: s = f.read()

def run_sudo_command(command):
    # Run a sudo command with password input
    process = subprocess.Popen(
        ['sudo', '-S'] + command,
        stdin=subprocess.PIPE,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )
    stdout, stderr = process.communicate(input=SUDO_PASSWORD + '\n')
    return stdout, stderr

def get_ssh(ip):
    # Use system call to nmap to check if port 22 is open with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-p', '22', '--open', '--host-timeout', timeout, ip])
    return "22/tcp open" in stdout

def get_dns_record(ip):
    try:
        return socket.gethostbyaddr(ip)[0]
    except socket.herror:
        return "No DNS record"

def get_mac_address(ip):
    # Use system call to nmap to perform an ARP scan with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-sn', '--host-timeout', timeout, ip])
    
    # Parse the output to find the MAC address
    lines = stdout.splitlines()
    for line in lines:
        if "MAC Address:" in line:
            return line.split("MAC Address:")[1].strip()
    return None

def get_os_info(ip):
    # Use system call to nmap to perform OS detection with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-O', '-Pn', '--host-timeout', timeout, ip])
    
    # Parse the output to find OS information
    lines = stdout.splitlines()
    os_info = []
    for line in lines:
        if "OS details:" in line:
            os_info.append(line.split("OS details:")[1].strip())
    return os_info if os_info else None

def create_excel_report(data, filename):
    wb = openpyxl.Workbook()
    for ip_range, results in data.items():
        ws = wb.create_sheet(title=filename)
        ws.append(['IP', 'MAC Address', 'Hostname', 'OS','SSH'])
        for result in results:
            # Convert OS list to a string
            if isinstance(result[3], list):
                result[3] = ", ".join(result[3])  # Join list elements into a single string
            ws.append(result)
    if 'Sheet' in wb.sheetnames:
        del wb['Sheet']
    wb.save(filename)

# %%
ip_ranges = [
    #"10.10.0.0/16",
    "10.20.0.0/24",
    "10.30.0.0/24",
    "10.40.0.0/24",
    "10.101.84.128/25",
    "10.101.84.0/25",
    "10.101.85.128/25",
    "10.101.86.0/23",
    "10.101.85.128/25",
    "10.101.148.0/22",
    "194.117.20.192/26"
    ]
all_results = {}


for ip_range in ip_ranges:
    ip_range_list = [str(ip) for ip in ipaddress.IPv4Network(ip_range.strip())]
    results = []
    for ip in ip_range_list:
        print(f"Checking {ip}")
        mac         = get_mac_address(ip)
        ssh_status  = get_ssh(ip)
        hostname    = get_dns_record(ip)
        os_info     = get_os_info(ip)
        
        results.append([ip, mac, hostname, os_info, ssh_status])
        print(f"Found {ip, mac, hostname, os_info, ssh_status}")
        all_results[ip_range] = results

    create_excel_report(results, f'range_{ip_range_list[0]}.xlsx')
    print(f"Report generated as 'range_{ip_range_list[0]}.xlsx'")

create_excel_report(results, f'range_{ip_range_list[0]}.xlsx')
print("Scan Completed")
# Out:
# Checking 10.20.0.0
# Found ('10.20.0.0', None, 'No DNS record', None, False)
# Checking 10.20.0.1
# Found ('10.20.0.1', None, 'No DNS record', None, True)
# Checking 10.20.0.2
# Found ('10.20.0.2', None, 'router-labmag.labmag.di.fc.ul.pt', None, False)
# Checking 10.20.0.3
# Found ('10.20.0.3', None, 'No DNS record', None, False)
# Checking 10.20.0.4
# Found ('10.20.0.4', None, 'No DNS record', None, False)
# Checking 10.20.0.5
# Found ('10.20.0.5', None, 'No DNS record', None, False)
# Checking 10.20.0.6
# Found ('10.20.0.6', None, 'No DNS record', None, False)
# Checking 10.20.0.7
# Found ('10.20.0.7', None, 'No DNS record', None, False)
# Checking 10.20.0.8
# Found ('10.20.0.8', None, 'No DNS record', None, False)
# Checking 10.20.0.9
# Found ('10.20.0.9', None, 'No DNS record', None, False)
# Checking 10.20.0.10
# Found ('10.20.0.10', None, 'No DNS record', None, False)
# Checking 10.20.0.11
# Found ('10.20.0.11', None, 'No DNS record', None, False)
# Checking 10.20.0.12
# Found ('10.20.0.12', None, 'No DNS record', None, False)
# Checking 10.20.0.13
# Found ('10.20.0.13', None, 'No DNS record', None, False)
# Checking 10.20.0.14
# Found ('10.20.0.14', None, 'No DNS record', None, False)
# Checking 10.20.0.15
# Found ('10.20.0.15', None, 'No DNS record', None, False)
# Checking 10.20.0.16
# Found ('10.20.0.16', None, 'No DNS record', None, False)
# Checking 10.20.0.17
# Found ('10.20.0.17', None, 'No DNS record', None, False)
# Checking 10.20.0.18
# Found ('10.20.0.18', None, 'No DNS record', None, False)
# Checking 10.20.0.19
# Found ('10.20.0.19', None, 'No DNS record', None, False)
# Checking 10.20.0.20
# Found ('10.20.0.20', None, 'No DNS record', None, False)
# Checking 10.20.0.21
# Found ('10.20.0.21', None, 'No DNS record', None, False)
# Checking 10.20.0.22
# Found ('10.20.0.22', None, 'No DNS record', None, False)
# Checking 10.20.0.23
# Found ('10.20.0.23', None, 'No DNS record', None, False)
# Checking 10.20.0.24
# Found ('10.20.0.24', None, 'No DNS record', None, False)
# Checking 10.20.0.25
# Found ('10.20.0.25', None, 'No DNS record', None, False)
# Checking 10.20.0.26
# Found ('10.20.0.26', None, 'No DNS record', None, False)
# Checking 10.20.0.27
# Found ('10.20.0.27', None, 'No DNS record', None, False)
# Checking 10.20.0.28
# Found ('10.20.0.28', None, 'No DNS record', None, False)
# Checking 10.20.0.29
# Found ('10.20.0.29', None, 'No DNS record', None, False)
# Checking 10.20.0.30
# Found ('10.20.0.30', None, 'No DNS record', None, False)
# Checking 10.20.0.31
# Found ('10.20.0.31', None, 'No DNS record', None, False)
# Checking 10.20.0.32
# Found ('10.20.0.32', None, 'No DNS record', None, False)
# Checking 10.20.0.33
# Found ('10.20.0.33', None, 'No DNS record', None, False)
# Checking 10.20.0.34
# Found ('10.20.0.34', None, 'No DNS record', None, False)
# Checking 10.20.0.35
# Found ('10.20.0.35', None, 'No DNS record', None, False)
# Checking 10.20.0.36
# Found ('10.20.0.36', None, 'No DNS record', None, False)
# Checking 10.20.0.37
# Found ('10.20.0.37', None, 'No DNS record', None, False)
# Checking 10.20.0.38
# Found ('10.20.0.38', None, 'No DNS record', None, False)
# Checking 10.20.0.39
# Found ('10.20.0.39', None, 'No DNS record', None, False)
# Checking 10.20.0.40
# Found ('10.20.0.40', None, 'No DNS record', None, False)
# Checking 10.20.0.41
# Found ('10.20.0.41', None, 'No DNS record', None, False)
# Checking 10.20.0.42
# Found ('10.20.0.42', None, 'No DNS record', None, False)
# Checking 10.20.0.43
# Found ('10.20.0.43', None, 'No DNS record', None, False)
# Checking 10.20.0.44
# Found ('10.20.0.44', None, 'No DNS record', None, False)
# Checking 10.20.0.45
# Found ('10.20.0.45', None, 'No DNS record', None, False)
# Checking 10.20.0.46
# Found ('10.20.0.46', None, 'No DNS record', None, False)
# Checking 10.20.0.47
# Found ('10.20.0.47', None, 'No DNS record', None, False)
# Checking 10.20.0.48
# Found ('10.20.0.48', None, 'No DNS record', None, False)
# Checking 10.20.0.49
# Found ('10.20.0.49', None, 'No DNS record', None, False)
# Checking 10.20.0.50
# Found ('10.20.0.50', None, 'No DNS record', None, False)
# Checking 10.20.0.51
# Found ('10.20.0.51', None, 'No DNS record', None, False)
# Checking 10.20.0.52
# Found ('10.20.0.52', None, 'No DNS record', None, False)
# Checking 10.20.0.53
# Found ('10.20.0.53', None, 'No DNS record', None, False)
# Checking 10.20.0.54
# Found ('10.20.0.54', None, 'No DNS record', None, False)
# Checking 10.20.0.55
# Found ('10.20.0.55', None, 'No DNS record', None, False)
# Checking 10.20.0.56
# Found ('10.20.0.56', None, 'No DNS record', None, False)
# Checking 10.20.0.57
# Found ('10.20.0.57', None, 'No DNS record', None, False)
# Checking 10.20.0.58
# Found ('10.20.0.58', None, 'No DNS record', None, False)
# Checking 10.20.0.59
# Found ('10.20.0.59', None, 'No DNS record', None, False)
# Checking 10.20.0.60
# Found ('10.20.0.60', None, 'No DNS record', None, False)
# Checking 10.20.0.61
# Found ('10.20.0.61', None, 'No DNS record', None, False)
# Checking 10.20.0.62
# Found ('10.20.0.62', None, 'No DNS record', None, False)
# Checking 10.20.0.63
# Found ('10.20.0.63', None, 'No DNS record', None, False)
# Checking 10.20.0.64
# Found ('10.20.0.64', None, 'No DNS record', None, False)
# Checking 10.20.0.65
# Found ('10.20.0.65', None, 'No DNS record', None, False)
# Checking 10.20.0.66
# Found ('10.20.0.66', None, 'No DNS record', None, False)
# Checking 10.20.0.67
# Found ('10.20.0.67', None, 'No DNS record', None, False)
# Checking 10.20.0.68
# Found ('10.20.0.68', None, 'No DNS record', None, False)
# Checking 10.20.0.69
# Found ('10.20.0.69', None, 'No DNS record', None, False)
# Checking 10.20.0.70
# Found ('10.20.0.70', None, 'No DNS record', None, False)
# Checking 10.20.0.71
# Found ('10.20.0.71', None, 'No DNS record', None, False)
# Checking 10.20.0.72
# Found ('10.20.0.72', None, 'No DNS record', None, False)
# Checking 10.20.0.73
# Found ('10.20.0.73', None, 'No DNS record', None, False)
# Checking 10.20.0.74
# Found ('10.20.0.74', None, 'No DNS record', None, False)
# Checking 10.20.0.75
# Found ('10.20.0.75', None, 'No DNS record', None, False)
# Checking 10.20.0.76
# Found ('10.20.0.76', None, 'No DNS record', None, False)
# Checking 10.20.0.77
# Found ('10.20.0.77', None, 'No DNS record', None, False)
# Checking 10.20.0.78
# Found ('10.20.0.78', None, 'No DNS record', None, False)
# Checking 10.20.0.79
# Found ('10.20.0.79', None, 'No DNS record', None, False)
# Checking 10.20.0.80
# Found ('10.20.0.80', None, 'No DNS record', None, False)
# Checking 10.20.0.81
# Found ('10.20.0.81', None, 'No DNS record', None, False)
# Checking 10.20.0.82
# Found ('10.20.0.82', None, 'No DNS record', None, False)
# Checking 10.20.0.83
# Found ('10.20.0.83', None, 'No DNS record', None, False)
# Checking 10.20.0.84
# Found ('10.20.0.84', None, 'No DNS record', None, False)
# Checking 10.20.0.85
# Found ('10.20.0.85', None, 'No DNS record', None, False)
# Checking 10.20.0.86
# Found ('10.20.0.86', None, 'No DNS record', None, False)
# Checking 10.20.0.87
# Found ('10.20.0.87', None, 'No DNS record', None, False)
# Checking 10.20.0.88
# Found ('10.20.0.88', None, 'No DNS record', None, False)
# Checking 10.20.0.89
# Found ('10.20.0.89', None, 'No DNS record', None, False)
# Checking 10.20.0.90
# Found ('10.20.0.90', None, 'No DNS record', None, False)
# Checking 10.20.0.91
# Found ('10.20.0.91', None, 'No DNS record', None, False)
# Checking 10.20.0.92
# Found ('10.20.0.92', None, 'No DNS record', None, False)
# Checking 10.20.0.93
# Found ('10.20.0.93', None, 'No DNS record', None, False)
# Checking 10.20.0.94
# Found ('10.20.0.94', None, 'No DNS record', None, False)
# Checking 10.20.0.95
# Found ('10.20.0.95', None, 'No DNS record', None, False)
# Checking 10.20.0.96
# Found ('10.20.0.96', None, 'No DNS record', None, False)
# Checking 10.20.0.97
# Found ('10.20.0.97', None, 'No DNS record', None, False)
# Checking 10.20.0.98
# Found ('10.20.0.98', None, 'No DNS record', None, False)
# Checking 10.20.0.99
# Found ('10.20.0.99', None, 'No DNS record', None, False)
# Checking 10.20.0.100
# Found ('10.20.0.100', None, 'No DNS record', None, False)
# Checking 10.20.0.101
# Found ('10.20.0.101', None, 'No DNS record', None, False)
# Checking 10.20.0.102
# Found ('10.20.0.102', None, 'No DNS record', None, False)
# Checking 10.20.0.103
# Found ('10.20.0.103', None, 'No DNS record', None, False)
# Checking 10.20.0.104
# Found ('10.20.0.104', None, 'No DNS record', None, False)
# Checking 10.20.0.105
# Found ('10.20.0.105', None, 'No DNS record', None, False)
# Checking 10.20.0.106
# Found ('10.20.0.106', None, 'No DNS record', None, False)
# Checking 10.20.0.107
# Found ('10.20.0.107', None, 'No DNS record', None, False)
# Checking 10.20.0.108
# Found ('10.20.0.108', None, 'No DNS record', None, False)
# Checking 10.20.0.109
# Found ('10.20.0.109', None, 'No DNS record', None, False)
# Checking 10.20.0.110
# Found ('10.20.0.110', None, 'No DNS record', None, False)
# Checking 10.20.0.111
# Found ('10.20.0.111', None, 'No DNS record', None, False)
# Checking 10.20.0.112
# Found ('10.20.0.112', None, 'No DNS record', None, False)
# Checking 10.20.0.113
# Found ('10.20.0.113', None, 'No DNS record', None, False)
# Checking 10.20.0.114
# Found ('10.20.0.114', None, 'No DNS record', None, False)
# Checking 10.20.0.115
# Found ('10.20.0.115', None, 'No DNS record', None, False)
# Checking 10.20.0.116
# Found ('10.20.0.116', None, 'No DNS record', None, False)
# Checking 10.20.0.117
# Found ('10.20.0.117', None, 'No DNS record', None, False)
# Checking 10.20.0.118
# Found ('10.20.0.118', None, 'No DNS record', None, False)
# Checking 10.20.0.119
# Found ('10.20.0.119', None, 'No DNS record', None, False)
# Checking 10.20.0.120
# Found ('10.20.0.120', None, 'No DNS record', None, False)
# Checking 10.20.0.121
# Found ('10.20.0.121', None, 'No DNS record', None, False)
# Checking 10.20.0.122
# Found ('10.20.0.122', None, 'No DNS record', None, False)
# Checking 10.20.0.123
# Found ('10.20.0.123', None, 'No DNS record', None, False)
# Checking 10.20.0.124
# Found ('10.20.0.124', None, 'No DNS record', None, False)
# Checking 10.20.0.125
# Found ('10.20.0.125', None, 'No DNS record', None, False)
# Checking 10.20.0.126
# Found ('10.20.0.126', None, 'No DNS record', None, False)
# Checking 10.20.0.127
# Found ('10.20.0.127', None, 'No DNS record', None, False)
# Checking 10.20.0.128
# Found ('10.20.0.128', None, 'No DNS record', None, False)
# Checking 10.20.0.129
# Found ('10.20.0.129', None, 'No DNS record', None, False)
# Checking 10.20.0.130
# Found ('10.20.0.130', None, 'No DNS record', None, False)
# Checking 10.20.0.131
# Found ('10.20.0.131', None, 'No DNS record', None, False)
# Checking 10.20.0.132
# Found ('10.20.0.132', None, 'No DNS record', None, False)
# Checking 10.20.0.133
# Found ('10.20.0.133', None, 'No DNS record', None, False)
# Checking 10.20.0.134
# Found ('10.20.0.134', None, 'No DNS record', None, False)
# Checking 10.20.0.135
# Found ('10.20.0.135', None, 'No DNS record', None, False)
# Checking 10.20.0.136
# Found ('10.20.0.136', None, 'No DNS record', None, False)
# Checking 10.20.0.137
# Found ('10.20.0.137', None, 'No DNS record', None, False)
# Checking 10.20.0.138
# Found ('10.20.0.138', None, 'No DNS record', None, False)
# Checking 10.20.0.139
# Found ('10.20.0.139', None, 'No DNS record', None, False)
# Checking 10.20.0.140
# Found ('10.20.0.140', None, 'No DNS record', None, False)
# Checking 10.20.0.141
# Found ('10.20.0.141', None, 'No DNS record', None, False)
# Checking 10.20.0.142
# Found ('10.20.0.142', None, 'No DNS record', None, False)
# Checking 10.20.0.143
# Found ('10.20.0.143', None, 'No DNS record', None, False)
# Checking 10.20.0.144
# Found ('10.20.0.144', None, 'No DNS record', None, False)
# Checking 10.20.0.145
# Found ('10.20.0.145', None, 'No DNS record', None, False)
# Checking 10.20.0.146
# Found ('10.20.0.146', None, 'No DNS record', None, False)
# Checking 10.20.0.147
# Found ('10.20.0.147', None, 'No DNS record', None, False)
# Checking 10.20.0.148
# Found ('10.20.0.148', None, 'No DNS record', None, False)
# Checking 10.20.0.149
# Found ('10.20.0.149', None, 'No DNS record', None, False)
# Checking 10.20.0.150
# Found ('10.20.0.150', None, 'No DNS record', None, False)
# Checking 10.20.0.151
# Found ('10.20.0.151', None, 'No DNS record', None, False)
# Checking 10.20.0.152
# Found ('10.20.0.152', None, 'No DNS record', None, False)
# Checking 10.20.0.153
# Found ('10.20.0.153', None, 'No DNS record', None, False)
# Checking 10.20.0.154
# Found ('10.20.0.154', None, 'No DNS record', None, False)
# Checking 10.20.0.155
# Found ('10.20.0.155', None, 'No DNS record', None, False)
# Checking 10.20.0.156
# Found ('10.20.0.156', None, 'No DNS record', None, False)
# Checking 10.20.0.157
# Found ('10.20.0.157', None, 'No DNS record', None, False)
# Checking 10.20.0.158
# Found ('10.20.0.158', None, 'No DNS record', None, False)
# Checking 10.20.0.159
# Found ('10.20.0.159', None, 'No DNS record', None, False)
# Checking 10.20.0.160
# Found ('10.20.0.160', None, 'No DNS record', None, False)
# Checking 10.20.0.161
# Found ('10.20.0.161', None, 'No DNS record', None, False)
# Checking 10.20.0.162
# Found ('10.20.0.162', None, 'No DNS record', None, False)
# Checking 10.20.0.163
# Found ('10.20.0.163', None, 'No DNS record', None, False)
# Checking 10.20.0.164
# Found ('10.20.0.164', None, 'No DNS record', None, False)
# Checking 10.20.0.165
# Found ('10.20.0.165', None, 'No DNS record', None, False)
# Checking 10.20.0.166
# Found ('10.20.0.166', None, 'No DNS record', None, False)
# Checking 10.20.0.167
# Found ('10.20.0.167', None, 'No DNS record', None, False)
# Checking 10.20.0.168
# Found ('10.20.0.168', None, 'No DNS record', None, False)
# Checking 10.20.0.169
# Found ('10.20.0.169', None, 'No DNS record', None, False)
# Checking 10.20.0.170
# Found ('10.20.0.170', None, 'No DNS record', None, False)
# Checking 10.20.0.171
# Found ('10.20.0.171', None, 'No DNS record', None, False)
# Checking 10.20.0.172
# Found ('10.20.0.172', None, 'No DNS record', None, False)
# Checking 10.20.0.173
# Found ('10.20.0.173', None, 'No DNS record', None, False)
# Checking 10.20.0.174
# Found ('10.20.0.174', None, 'No DNS record', None, False)
# Checking 10.20.0.175
# Found ('10.20.0.175', None, 'No DNS record', None, False)
# Checking 10.20.0.176
# Found ('10.20.0.176', None, 'No DNS record', None, False)
# Checking 10.20.0.177
# Found ('10.20.0.177', None, 'No DNS record', None, False)
# Checking 10.20.0.178
# Found ('10.20.0.178', None, 'No DNS record', None, False)
# Checking 10.20.0.179
# Found ('10.20.0.179', None, 'No DNS record', None, False)
# Checking 10.20.0.180
# Found ('10.20.0.180', None, 'No DNS record', None, False)
# Checking 10.20.0.181
# Found ('10.20.0.181', None, 'No DNS record', None, False)
# Checking 10.20.0.182
# Found ('10.20.0.182', None, 'No DNS record', None, False)
# Checking 10.20.0.183
# Found ('10.20.0.183', None, 'No DNS record', None, False)
# Checking 10.20.0.184
# Found ('10.20.0.184', None, 'No DNS record', None, False)
# Checking 10.20.0.185
# Found ('10.20.0.185', None, 'No DNS record', None, False)
# Checking 10.20.0.186
# Found ('10.20.0.186', None, 'No DNS record', None, False)
# Checking 10.20.0.187
# Found ('10.20.0.187', None, 'No DNS record', None, False)
# Checking 10.20.0.188
# Found ('10.20.0.188', None, 'No DNS record', None, False)
# Checking 10.20.0.189
# Found ('10.20.0.189', None, 'No DNS record', None, False)
# Checking 10.20.0.190
# Found ('10.20.0.190', None, 'No DNS record', None, False)
# Checking 10.20.0.191
# Found ('10.20.0.191', None, 'No DNS record', None, False)
# Checking 10.20.0.192
# Found ('10.20.0.192', None, 'No DNS record', None, False)
# Checking 10.20.0.193
# Found ('10.20.0.193', None, 'No DNS record', None, False)
# Checking 10.20.0.194
# Found ('10.20.0.194', None, 'No DNS record', None, False)
# Checking 10.20.0.195
# Found ('10.20.0.195', None, 'No DNS record', None, False)
# Checking 10.20.0.196
# Found ('10.20.0.196', None, 'No DNS record', None, False)
# Checking 10.20.0.197
# Found ('10.20.0.197', None, 'No DNS record', None, False)
# Checking 10.20.0.198
# Found ('10.20.0.198', None, 'No DNS record', None, False)
# Checking 10.20.0.199
# Found ('10.20.0.199', None, 'No DNS record', None, False)
# Checking 10.20.0.200
# Found ('10.20.0.200', None, 'No DNS record', None, False)
# Checking 10.20.0.201
# Found ('10.20.0.201', None, 'No DNS record', None, False)
# Checking 10.20.0.202
# Found ('10.20.0.202', None, 'No DNS record', None, False)
# Checking 10.20.0.203
# Found ('10.20.0.203', None, 'No DNS record', None, False)
# Checking 10.20.0.204
# Found ('10.20.0.204', None, 'No DNS record', None, False)
# Checking 10.20.0.205
# Found ('10.20.0.205', None, 'No DNS record', None, False)
# Checking 10.20.0.206
# Found ('10.20.0.206', None, 'No DNS record', None, False)
# Checking 10.20.0.207
# Found ('10.20.0.207', None, 'No DNS record', None, False)
# Checking 10.20.0.208
# Found ('10.20.0.208', None, 'No DNS record', None, False)
# Checking 10.20.0.209
# Found ('10.20.0.209', None, 'No DNS record', None, False)
# Checking 10.20.0.210
# Found ('10.20.0.210', None, 'No DNS record', None, False)
# Checking 10.20.0.211
# Found ('10.20.0.211', None, 'No DNS record', None, False)
# Checking 10.20.0.212
# Found ('10.20.0.212', None, 'No DNS record', None, False)
# Checking 10.20.0.213
# Found ('10.20.0.213', None, 'No DNS record', None, False)
# Checking 10.20.0.214
# Found ('10.20.0.214', None, 'No DNS record', None, False)
# Checking 10.20.0.215
# Found ('10.20.0.215', None, 'No DNS record', None, False)
# Checking 10.20.0.216
# Found ('10.20.0.216', None, 'No DNS record', None, False)
# Checking 10.20.0.217
# Found ('10.20.0.217', None, 'No DNS record', None, False)
# Checking 10.20.0.218
# Found ('10.20.0.218', None, 'No DNS record', None, False)
# Checking 10.20.0.219
# Found ('10.20.0.219', None, 'No DNS record', None, False)
# Checking 10.20.0.220
# Found ('10.20.0.220', None, 'No DNS record', None, False)
# Checking 10.20.0.221
# Found ('10.20.0.221', None, 'No DNS record', None, False)
# Checking 10.20.0.222
# Found ('10.20.0.222', None, 'No DNS record', None, False)
# Checking 10.20.0.223
# Found ('10.20.0.223', None, 'No DNS record', None, False)
# Checking 10.20.0.224
# Found ('10.20.0.224', None, 'No DNS record', None, False)
# Checking 10.20.0.225
# Found ('10.20.0.225', None, 'No DNS record', None, False)
# Checking 10.20.0.226
# Found ('10.20.0.226', None, 'No DNS record', None, False)
# Checking 10.20.0.227
# Found ('10.20.0.227', None, 'No DNS record', None, False)
# Checking 10.20.0.228
# Found ('10.20.0.228', None, 'No DNS record', None, False)
# Checking 10.20.0.229
# Found ('10.20.0.229', None, 'No DNS record', None, False)
# Checking 10.20.0.230
# Found ('10.20.0.230', None, 'No DNS record', None, False)
# Checking 10.20.0.231
# Found ('10.20.0.231', None, 'No DNS record', None, False)
# Checking 10.20.0.232
# Found ('10.20.0.232', None, 'No DNS record', None, False)
# Checking 10.20.0.233
# Found ('10.20.0.233', None, 'No DNS record', None, False)
# Checking 10.20.0.234
# Found ('10.20.0.234', None, 'No DNS record', None, False)
# Checking 10.20.0.235
# Found ('10.20.0.235', None, 'No DNS record', None, False)
# Checking 10.20.0.236
# Found ('10.20.0.236', None, 'No DNS record', None, False)
# Checking 10.20.0.237
# Found ('10.20.0.237', None, 'No DNS record', None, False)
# Checking 10.20.0.238
# Found ('10.20.0.238', None, 'No DNS record', None, False)
# Checking 10.20.0.239
# Found ('10.20.0.239', None, 'No DNS record', None, False)
# Checking 10.20.0.240
# Found ('10.20.0.240', None, 'No DNS record', None, False)
# Checking 10.20.0.241
# Found ('10.20.0.241', None, 'No DNS record', None, False)
# Checking 10.20.0.242
# Found ('10.20.0.242', None, 'No DNS record', None, False)
# Checking 10.20.0.243
# Found ('10.20.0.243', None, 'No DNS record', None, False)
# Checking 10.20.0.244
# Found ('10.20.0.244', None, 'No DNS record', None, False)
# Checking 10.20.0.245
# Found ('10.20.0.245', None, 'No DNS record', None, False)
# Checking 10.20.0.246
# Found ('10.20.0.246', None, 'No DNS record', None, False)
# Checking 10.20.0.247
# Found ('10.20.0.247', None, 'No DNS record', None, False)
# Checking 10.20.0.248
# Found ('10.20.0.248', None, 'No DNS record', None, False)
# Checking 10.20.0.249
# Found ('10.20.0.249', None, 'No DNS record', None, False)
# Checking 10.20.0.250
# Found ('10.20.0.250', None, 'No DNS record', None, False)
# Checking 10.20.0.251
# Found ('10.20.0.251', None, 'No DNS record', None, False)
# Checking 10.20.0.252
# Found ('10.20.0.252', None, 'No DNS record', None, False)
# Checking 10.20.0.253
# Found ('10.20.0.253', None, 'No DNS record', None, False)
# Checking 10.20.0.254
# Found ('10.20.0.254', None, 'No DNS record', None, False)
# Checking 10.20.0.255
# Found ('10.20.0.255', None, 'No DNS record', None, False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 31
#      28         print(f"Found {ip, mac, hostname, os_info, ssh_status}")
#      29         all_results[ip_range] = results
# ---> 31     create_excel_report(results, f'range_{ip_range_list[0]}.xlsx')
#      32     print(f"Report generated as 'range_{ip_range_list[0]}.xlsx'")
#      34 create_excel_report(results, f'range_{ip_range_list[0]}.xlsx')
#
# Cell In[5], line 65, in create_excel_report(data, filename)
#      63 def create_excel_report(data, filename):
#      64     wb = openpyxl.Workbook()
# ---> 65     print(data.items())
#      66     for ip_range, results in data.items():
#      67         ws = wb.create_sheet(title=filename)
#
# AttributeError: 'list' object has no attribute 'items'
