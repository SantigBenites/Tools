# %%
import nmap
import paramiko
import openpyxl
import socket
import re
import ipaddress

# %%
import paramiko
import openpyxl
import socket
import re
import ipaddress
import subprocess
import os

# Define your sudo password in a file in the same directory called sudopass
SUDO_PASSWORD = "password"
timeout = "1s"
with open(f'{os.getcwd()}/sudopass') as f: 
    SUDO_PASSWORD = f.read()

with open('sudopass') as f: s = f.read()

def run_sudo_command(command):
    # Run a sudo command with password input
    process = subprocess.Popen(
        ['sudo', '-S'] + command,
        stdin=subprocess.PIPE,
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        text=True
    )
    stdout, stderr = process.communicate(input=SUDO_PASSWORD + '\n')
    return stdout, stderr

def get_ssh(ip):
    # Use system call to nmap to check if port 22 is open with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-p', '22', '--open', '--host-timeout', timeout, ip])
    return "22/tcp open" in stdout

def get_dns_record(ip):
    try:
        return socket.gethostbyaddr(ip)[0]
    except socket.herror:
        return "No DNS record"

def get_mac_address(ip):
    # Use system call to nmap to perform an ARP scan with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-sn', '--host-timeout', timeout, ip])
    
    # Parse the output to find the MAC address
    lines = stdout.splitlines()
    for line in lines:
        if "MAC Address:" in line:
            return line.split("MAC Address:")[1].strip()
    return None

def get_os_info(ip):
    # Use system call to nmap to perform OS detection with a timeout
    stdout, stderr = run_sudo_command(['nmap', '-T', '4', '-O', '-Pn', '--host-timeout', timeout, ip])
    
    # Parse the output to find OS information
    lines = stdout.splitlines()
    os_info = []
    for line in lines:
        if "OS details:" in line:
            os_info.append(line.split("OS details:")[1].strip())
    return os_info if os_info else None

def create_excel_report(data, filename):
    wb = openpyxl.Workbook()
    for ip_range, results in data.items():
        ws = wb.create_sheet(title=ip_range)
        ws.append(['IP', 'MAC Address', 'Hostname', 'OS','SSH'])
        for result in results:
            # Convert OS list to a string
            if isinstance(result[3], list):
                result[3] = ", ".join(result[3])  # Join list elements into a single string
            ws.append(result)
    if 'Sheet' in wb.sheetnames:
        del wb['Sheet']
    wb.save(filename)

# %%
ip_ranges = [
    #"10.10.0.0/16",
    "10.10.20.0/24",
    "10.30.0.0/24",
    "10.40.0.0/24",
    "10.101.84.128/25",
    "10.101.84.0/25",
    "10.101.85.128/25",
    "10.101.86.0/23",
    "10.101.85.128/25",
    "10.101.148.0/22",
    "194.117.20.192/26"
    ]
all_results = {}


for ip_range in ip_ranges:
    ip_range_list = [str(ip) for ip in ipaddress.IPv4Network(ip_range.strip())]
    results = []
    for ip in ip_range_list:
        print(f"Checking {ip}")
        mac         = get_mac_address(ip)
        ssh_status  = get_ssh(ip)
        hostname    = get_dns_record(ip)
        os_info     = get_os_info(ip)
        
        results.append([ip, mac, hostname, os_info, ssh_status])
        print(f"Found {ip, mac, hostname, os_info, ssh_status}")
        all_results[ip_range] = results

    create_excel_report(all_results, f'range_{ip_range}.xlsx')
    print(f"Report generated as 'range_{ip_range}.xlsx'")

print("Scan Completed")
# Out:
# Checking 10.10.20.0
# Found ('10.10.20.0', None, 'No DNS record', None, False)
# Checking 10.10.20.1
# Found ('10.10.20.1', None, 'No DNS record', None, False)
# Checking 10.10.20.2
# Found ('10.10.20.2', None, 'No DNS record', None, False)
# Checking 10.10.20.3
# Found ('10.10.20.3', None, 'No DNS record', None, False)
# Checking 10.10.20.4
# Found ('10.10.20.4', None, 'No DNS record', None, False)
# Checking 10.10.20.5
# Found ('10.10.20.5', None, 'No DNS record', None, False)
# Checking 10.10.20.6
# Found ('10.10.20.6', None, 'No DNS record', None, False)
# Checking 10.10.20.7
# Found ('10.10.20.7', None, 'No DNS record', None, False)
# Checking 10.10.20.8
# Found ('10.10.20.8', None, 'No DNS record', None, False)
# Checking 10.10.20.9
# Found ('10.10.20.9', None, 'No DNS record', None, False)
# Checking 10.10.20.10
# Found ('10.10.20.10', None, 'No DNS record', None, False)
# Checking 10.10.20.11
# Found ('10.10.20.11', None, 'No DNS record', None, False)
# Checking 10.10.20.12
# Found ('10.10.20.12', None, 'No DNS record', None, False)
# Checking 10.10.20.13
# Found ('10.10.20.13', None, 'No DNS record', None, False)
# Checking 10.10.20.14
# Found ('10.10.20.14', None, 'No DNS record', None, False)
# Checking 10.10.20.15
# Found ('10.10.20.15', None, 'No DNS record', None, False)
# Checking 10.10.20.16
# Found ('10.10.20.16', None, 'No DNS record', None, False)
# Checking 10.10.20.17
# Found ('10.10.20.17', None, 'No DNS record', None, False)
# Checking 10.10.20.18
# Found ('10.10.20.18', None, 'No DNS record', None, False)
# Checking 10.10.20.19
# Found ('10.10.20.19', None, 'No DNS record', None, False)
# Checking 10.10.20.20
# Found ('10.10.20.20', None, 'No DNS record', None, False)
# Checking 10.10.20.21
# Found ('10.10.20.21', None, 'No DNS record', None, False)
# Checking 10.10.20.22
# Found ('10.10.20.22', None, 'No DNS record', None, False)
# Checking 10.10.20.23
# Found ('10.10.20.23', None, 'No DNS record', None, False)
# Checking 10.10.20.24
# Found ('10.10.20.24', None, 'No DNS record', None, False)
# Checking 10.10.20.25
# Found ('10.10.20.25', None, 'No DNS record', None, False)
# Checking 10.10.20.26
# Found ('10.10.20.26', None, 'No DNS record', None, False)
# Checking 10.10.20.27
# Found ('10.10.20.27', None, 'No DNS record', None, False)
# Checking 10.10.20.28
# Found ('10.10.20.28', None, 'No DNS record', None, False)
# Checking 10.10.20.29
# Found ('10.10.20.29', None, 'No DNS record', None, False)
# Checking 10.10.20.30
# Found ('10.10.20.30', None, 'No DNS record', None, False)
# Checking 10.10.20.31
# Found ('10.10.20.31', None, 'No DNS record', None, False)
# Checking 10.10.20.32
# Found ('10.10.20.32', None, 'No DNS record', None, False)
# Checking 10.10.20.33
# Found ('10.10.20.33', None, 'No DNS record', None, False)
# Checking 10.10.20.34
# Found ('10.10.20.34', None, 'No DNS record', None, False)
# Checking 10.10.20.35
# Found ('10.10.20.35', None, 'No DNS record', None, False)
# Checking 10.10.20.36
# Found ('10.10.20.36', None, 'No DNS record', None, False)
# Checking 10.10.20.37
# Found ('10.10.20.37', None, 'No DNS record', None, False)
# Checking 10.10.20.38
# Found ('10.10.20.38', None, 'No DNS record', None, False)
# Checking 10.10.20.39
# Found ('10.10.20.39', None, 'No DNS record', None, False)
# Checking 10.10.20.40
# Found ('10.10.20.40', None, 'No DNS record', None, False)
# Checking 10.10.20.41
# Found ('10.10.20.41', None, 'No DNS record', None, False)
# Checking 10.10.20.42
# Found ('10.10.20.42', None, 'No DNS record', None, False)
# Checking 10.10.20.43
# Found ('10.10.20.43', None, 'No DNS record', None, False)
# Checking 10.10.20.44
# Found ('10.10.20.44', None, 'No DNS record', None, False)
# Checking 10.10.20.45
# Found ('10.10.20.45', None, 'No DNS record', None, False)
# Checking 10.10.20.46
# Found ('10.10.20.46', None, 'No DNS record', None, False)
# Checking 10.10.20.47
# Found ('10.10.20.47', None, 'No DNS record', None, False)
# Checking 10.10.20.48
# Found ('10.10.20.48', None, 'No DNS record', None, False)
# Checking 10.10.20.49
# Found ('10.10.20.49', None, 'No DNS record', None, False)
# Checking 10.10.20.50
# Found ('10.10.20.50', None, 'No DNS record', None, False)
# Checking 10.10.20.51
# Found ('10.10.20.51', None, 'No DNS record', None, False)
# Checking 10.10.20.52
# Found ('10.10.20.52', None, 'No DNS record', None, False)
# Checking 10.10.20.53
# Found ('10.10.20.53', None, 'No DNS record', None, False)
# Checking 10.10.20.54
# Found ('10.10.20.54', None, 'No DNS record', None, False)
# Checking 10.10.20.55
# Found ('10.10.20.55', None, 'No DNS record', None, False)
# Checking 10.10.20.56
# Found ('10.10.20.56', None, 'No DNS record', None, False)
# Checking 10.10.20.57
# Found ('10.10.20.57', None, 'No DNS record', None, False)
# Checking 10.10.20.58
# Found ('10.10.20.58', None, 'No DNS record', None, False)
# Checking 10.10.20.59
# Found ('10.10.20.59', None, 'No DNS record', None, False)
# Checking 10.10.20.60
# Found ('10.10.20.60', None, 'No DNS record', None, False)
# Checking 10.10.20.61
# Found ('10.10.20.61', None, 'No DNS record', None, False)
# Checking 10.10.20.62
# Found ('10.10.20.62', None, 'No DNS record', None, False)
# Checking 10.10.20.63
# Found ('10.10.20.63', None, 'No DNS record', None, False)
# Checking 10.10.20.64
# Found ('10.10.20.64', None, 'No DNS record', None, False)
# Checking 10.10.20.65
# Found ('10.10.20.65', None, 'No DNS record', None, False)
# Checking 10.10.20.66
# Found ('10.10.20.66', None, 'No DNS record', None, False)
# Checking 10.10.20.67
# Found ('10.10.20.67', None, 'No DNS record', None, False)
# Checking 10.10.20.68
# Found ('10.10.20.68', None, 'No DNS record', None, False)
# Checking 10.10.20.69
# Found ('10.10.20.69', None, 'No DNS record', None, False)
# Checking 10.10.20.70
# Found ('10.10.20.70', None, 'No DNS record', None, False)
# Checking 10.10.20.71
# Found ('10.10.20.71', None, 'No DNS record', None, False)
# Checking 10.10.20.72
# Found ('10.10.20.72', None, 'No DNS record', None, False)
# Checking 10.10.20.73
# Found ('10.10.20.73', None, 'No DNS record', None, False)
# Checking 10.10.20.74
# Found ('10.10.20.74', None, 'No DNS record', None, False)
# Checking 10.10.20.75
# Found ('10.10.20.75', None, 'No DNS record', None, False)
# Checking 10.10.20.76
# Found ('10.10.20.76', None, 'No DNS record', None, False)
# Checking 10.10.20.77
# Found ('10.10.20.77', None, 'No DNS record', None, False)
# Checking 10.10.20.78
# Found ('10.10.20.78', None, 'No DNS record', None, False)
# Checking 10.10.20.79
# Found ('10.10.20.79', None, 'No DNS record', None, False)
# Checking 10.10.20.80
# Found ('10.10.20.80', None, 'No DNS record', None, False)
# Checking 10.10.20.81
# Found ('10.10.20.81', None, 'No DNS record', None, False)
# Checking 10.10.20.82
# Found ('10.10.20.82', None, 'No DNS record', None, False)
# Checking 10.10.20.83
# Found ('10.10.20.83', None, 'No DNS record', None, False)
# Checking 10.10.20.84
# Found ('10.10.20.84', None, 'No DNS record', None, False)
# Checking 10.10.20.85
# Found ('10.10.20.85', None, 'No DNS record', None, False)
# Checking 10.10.20.86
# Found ('10.10.20.86', None, 'No DNS record', None, False)
# Checking 10.10.20.87
# Found ('10.10.20.87', None, 'No DNS record', None, False)
# Checking 10.10.20.88
# Found ('10.10.20.88', None, 'No DNS record', None, False)
# Checking 10.10.20.89
# Found ('10.10.20.89', None, 'No DNS record', None, False)
# Checking 10.10.20.90
# Found ('10.10.20.90', None, 'No DNS record', None, False)
# Checking 10.10.20.91
# Found ('10.10.20.91', None, 'No DNS record', None, False)
# Checking 10.10.20.92
# Found ('10.10.20.92', None, 'No DNS record', None, False)
# Checking 10.10.20.93
# Found ('10.10.20.93', None, 'No DNS record', None, False)
# Checking 10.10.20.94
# Found ('10.10.20.94', None, 'No DNS record', None, False)
# Checking 10.10.20.95
# Found ('10.10.20.95', None, 'No DNS record', None, False)
# Checking 10.10.20.96
# Found ('10.10.20.96', None, 'No DNS record', None, False)
# Checking 10.10.20.97
# Found ('10.10.20.97', None, 'No DNS record', None, False)
# Checking 10.10.20.98
# Found ('10.10.20.98', None, 'No DNS record', None, False)
# Checking 10.10.20.99
# Found ('10.10.20.99', None, 'No DNS record', None, False)
# Checking 10.10.20.100
# Found ('10.10.20.100', None, 'No DNS record', None, False)
# Checking 10.10.20.101
# Found ('10.10.20.101', None, 'No DNS record', None, False)
# Checking 10.10.20.102
# Found ('10.10.20.102', None, 'No DNS record', None, False)
# Checking 10.10.20.103
# Found ('10.10.20.103', None, 'No DNS record', None, False)
# Checking 10.10.20.104
# Found ('10.10.20.104', None, 'No DNS record', None, False)
# Checking 10.10.20.105
# Found ('10.10.20.105', None, 'No DNS record', None, False)
# Checking 10.10.20.106
# Found ('10.10.20.106', None, 'No DNS record', None, False)
# Checking 10.10.20.107
# Found ('10.10.20.107', None, 'No DNS record', None, False)
# Checking 10.10.20.108
# Found ('10.10.20.108', None, 'No DNS record', None, False)
# Checking 10.10.20.109
# Found ('10.10.20.109', None, 'No DNS record', None, False)
# Checking 10.10.20.110
# Found ('10.10.20.110', None, 'No DNS record', None, False)
# Checking 10.10.20.111
# Found ('10.10.20.111', None, 'No DNS record', None, False)
# Checking 10.10.20.112
# Found ('10.10.20.112', None, 'No DNS record', None, False)
# Checking 10.10.20.113
# Found ('10.10.20.113', None, 'No DNS record', None, False)
# Checking 10.10.20.114
# Found ('10.10.20.114', None, 'No DNS record', None, False)
# Checking 10.10.20.115
# Found ('10.10.20.115', None, 'No DNS record', None, False)
# Checking 10.10.20.116
# Found ('10.10.20.116', None, 'No DNS record', None, False)
# Checking 10.10.20.117
# Found ('10.10.20.117', None, 'No DNS record', None, False)
# Checking 10.10.20.118
# Found ('10.10.20.118', None, 'No DNS record', None, False)
# Checking 10.10.20.119
# Found ('10.10.20.119', None, 'No DNS record', None, False)
# Checking 10.10.20.120
# Found ('10.10.20.120', None, 'No DNS record', None, False)
# Checking 10.10.20.121
# Found ('10.10.20.121', None, 'No DNS record', None, False)
# Checking 10.10.20.122
# Found ('10.10.20.122', None, 'No DNS record', None, False)
# Checking 10.10.20.123
# Found ('10.10.20.123', None, 'No DNS record', None, False)
# Checking 10.10.20.124
# Found ('10.10.20.124', None, 'No DNS record', None, False)
# Checking 10.10.20.125
# Found ('10.10.20.125', None, 'No DNS record', None, False)
# Checking 10.10.20.126
# Found ('10.10.20.126', None, 'No DNS record', None, False)
# Checking 10.10.20.127
# Found ('10.10.20.127', None, 'No DNS record', None, False)
# Checking 10.10.20.128
# Found ('10.10.20.128', None, 'No DNS record', None, False)
# Checking 10.10.20.129
# Found ('10.10.20.129', None, 'No DNS record', None, False)
# Checking 10.10.20.130
# Found ('10.10.20.130', None, 'No DNS record', None, False)
# Checking 10.10.20.131
# Found ('10.10.20.131', None, 'No DNS record', None, False)
# Checking 10.10.20.132
# Found ('10.10.20.132', None, 'No DNS record', None, False)
# Checking 10.10.20.133
# Found ('10.10.20.133', None, 'No DNS record', None, False)
# Checking 10.10.20.134
# Found ('10.10.20.134', None, 'No DNS record', None, False)
# Checking 10.10.20.135
# Found ('10.10.20.135', None, 'No DNS record', None, False)
# Checking 10.10.20.136
# Found ('10.10.20.136', None, 'No DNS record', None, False)
# Checking 10.10.20.137
# Found ('10.10.20.137', None, 'No DNS record', None, False)
# Checking 10.10.20.138
# Found ('10.10.20.138', None, 'No DNS record', None, False)
# Checking 10.10.20.139
# Found ('10.10.20.139', None, 'No DNS record', None, False)
# Checking 10.10.20.140
# Found ('10.10.20.140', None, 'No DNS record', None, False)
# Checking 10.10.20.141
# Found ('10.10.20.141', None, 'No DNS record', None, False)
# Checking 10.10.20.142
# Found ('10.10.20.142', None, 'No DNS record', None, False)
# Checking 10.10.20.143
# Found ('10.10.20.143', None, 'No DNS record', None, False)
# Checking 10.10.20.144
# Found ('10.10.20.144', None, 'No DNS record', None, False)
# Checking 10.10.20.145
# Found ('10.10.20.145', None, 'No DNS record', None, False)
# Checking 10.10.20.146
# Found ('10.10.20.146', None, 'No DNS record', None, False)
# Checking 10.10.20.147
# Found ('10.10.20.147', None, 'No DNS record', None, False)
# Checking 10.10.20.148
# Found ('10.10.20.148', None, 'No DNS record', None, False)
# Checking 10.10.20.149
# Found ('10.10.20.149', None, 'No DNS record', None, False)
# Checking 10.10.20.150
# Found ('10.10.20.150', None, 'No DNS record', None, False)
# Checking 10.10.20.151
# Found ('10.10.20.151', None, 'No DNS record', None, False)
# Checking 10.10.20.152
# Found ('10.10.20.152', None, 'No DNS record', None, False)
# Checking 10.10.20.153
# Found ('10.10.20.153', None, 'No DNS record', None, False)
# Checking 10.10.20.154
# Found ('10.10.20.154', None, 'No DNS record', None, False)
# Checking 10.10.20.155
# Found ('10.10.20.155', None, 'No DNS record', None, False)
# Checking 10.10.20.156
# Found ('10.10.20.156', None, 'No DNS record', None, False)
# Checking 10.10.20.157
# Found ('10.10.20.157', None, 'No DNS record', None, False)
# Checking 10.10.20.158
# Found ('10.10.20.158', None, 'No DNS record', None, False)
# Checking 10.10.20.159
# Found ('10.10.20.159', None, 'No DNS record', None, False)
# Checking 10.10.20.160
# Found ('10.10.20.160', None, 'No DNS record', None, False)
# Checking 10.10.20.161
# Found ('10.10.20.161', None, 'No DNS record', None, False)
# Checking 10.10.20.162
# Found ('10.10.20.162', None, 'No DNS record', None, False)
# Checking 10.10.20.163
# Found ('10.10.20.163', None, 'No DNS record', None, False)
# Checking 10.10.20.164
# Found ('10.10.20.164', None, 'No DNS record', None, False)
# Checking 10.10.20.165
# Found ('10.10.20.165', None, 'No DNS record', None, False)
# Checking 10.10.20.166
# Found ('10.10.20.166', None, 'No DNS record', None, False)
# Checking 10.10.20.167
# Found ('10.10.20.167', None, 'No DNS record', None, False)
# Checking 10.10.20.168
# Found ('10.10.20.168', None, 'No DNS record', None, False)
# Checking 10.10.20.169
# Found ('10.10.20.169', None, 'No DNS record', None, False)
# Checking 10.10.20.170
# Found ('10.10.20.170', None, 'No DNS record', None, False)
# Checking 10.10.20.171
# Found ('10.10.20.171', None, 'No DNS record', None, False)
# Checking 10.10.20.172
# Found ('10.10.20.172', None, 'No DNS record', None, False)
# Checking 10.10.20.173
# Found ('10.10.20.173', None, 'No DNS record', None, False)
# Checking 10.10.20.174
# Found ('10.10.20.174', None, 'No DNS record', None, False)
# Checking 10.10.20.175
# Found ('10.10.20.175', None, 'No DNS record', None, False)
# Checking 10.10.20.176
# Found ('10.10.20.176', None, 'No DNS record', None, False)
# Checking 10.10.20.177
# Found ('10.10.20.177', None, 'No DNS record', None, False)
# Checking 10.10.20.178
# Found ('10.10.20.178', None, 'No DNS record', None, False)
# Checking 10.10.20.179
# Found ('10.10.20.179', None, 'No DNS record', None, False)
# Checking 10.10.20.180
# Found ('10.10.20.180', None, 'No DNS record', None, False)
# Checking 10.10.20.181
# Found ('10.10.20.181', None, 'No DNS record', None, False)
# Checking 10.10.20.182
# Found ('10.10.20.182', None, 'No DNS record', None, False)
# Checking 10.10.20.183
# Found ('10.10.20.183', None, 'No DNS record', None, False)
# Checking 10.10.20.184
# Found ('10.10.20.184', None, 'No DNS record', None, False)
# Checking 10.10.20.185
# Found ('10.10.20.185', None, 'No DNS record', None, False)
# Checking 10.10.20.186
# Found ('10.10.20.186', None, 'No DNS record', None, False)
# Checking 10.10.20.187
# Found ('10.10.20.187', None, 'No DNS record', None, False)
# Checking 10.10.20.188
# Found ('10.10.20.188', None, 'No DNS record', None, False)
# Checking 10.10.20.189
# Found ('10.10.20.189', None, 'No DNS record', None, False)
# Checking 10.10.20.190
# Found ('10.10.20.190', None, 'No DNS record', None, False)
# Checking 10.10.20.191
# Found ('10.10.20.191', None, 'No DNS record', None, False)
# Checking 10.10.20.192
# Found ('10.10.20.192', None, 'No DNS record', None, False)
# Checking 10.10.20.193
# Found ('10.10.20.193', None, 'No DNS record', None, False)
# Checking 10.10.20.194
# Found ('10.10.20.194', None, 'No DNS record', None, False)
# Checking 10.10.20.195
# Found ('10.10.20.195', None, 'No DNS record', None, False)
# Checking 10.10.20.196
# Found ('10.10.20.196', None, 'No DNS record', None, False)
# Checking 10.10.20.197
# Found ('10.10.20.197', None, 'No DNS record', None, False)
# Checking 10.10.20.198
# Found ('10.10.20.198', None, 'No DNS record', None, False)
# Checking 10.10.20.199
# Found ('10.10.20.199', None, 'No DNS record', None, False)
# Checking 10.10.20.200
# Found ('10.10.20.200', None, 'No DNS record', None, False)
# Checking 10.10.20.201
# Found ('10.10.20.201', None, 'No DNS record', None, False)
# Checking 10.10.20.202
# Found ('10.10.20.202', None, 'No DNS record', None, False)
# Checking 10.10.20.203
# Found ('10.10.20.203', None, 'No DNS record', None, False)
# Checking 10.10.20.204
# Found ('10.10.20.204', None, 'No DNS record', None, False)
# Checking 10.10.20.205
# Found ('10.10.20.205', None, 'No DNS record', None, False)
# Checking 10.10.20.206
# Found ('10.10.20.206', None, 'No DNS record', None, False)
# Checking 10.10.20.207
# Found ('10.10.20.207', None, 'No DNS record', None, False)
# Checking 10.10.20.208
# Found ('10.10.20.208', None, 'No DNS record', None, False)
# Checking 10.10.20.209
# Found ('10.10.20.209', None, 'No DNS record', None, False)
# Checking 10.10.20.210
# Found ('10.10.20.210', None, 'No DNS record', None, False)
# Checking 10.10.20.211
# Found ('10.10.20.211', None, 'No DNS record', None, False)
# Checking 10.10.20.212
# Found ('10.10.20.212', None, 'No DNS record', None, False)
# Checking 10.10.20.213
# Found ('10.10.20.213', None, 'No DNS record', None, False)
# Checking 10.10.20.214
# Found ('10.10.20.214', None, 'No DNS record', None, False)
# Checking 10.10.20.215
# Found ('10.10.20.215', None, 'No DNS record', None, False)
# Checking 10.10.20.216
# Found ('10.10.20.216', None, 'No DNS record', None, False)
# Checking 10.10.20.217
# Found ('10.10.20.217', None, 'No DNS record', None, False)
# Checking 10.10.20.218
# Found ('10.10.20.218', None, 'No DNS record', None, False)
# Checking 10.10.20.219
# Found ('10.10.20.219', None, 'No DNS record', None, False)
# Checking 10.10.20.220
# Found ('10.10.20.220', None, 'No DNS record', None, False)
# Checking 10.10.20.221
# Found ('10.10.20.221', None, 'No DNS record', None, False)
# Checking 10.10.20.222
# Found ('10.10.20.222', None, 'No DNS record', None, False)
# Checking 10.10.20.223
# Found ('10.10.20.223', None, 'No DNS record', None, False)
# Checking 10.10.20.224
# Found ('10.10.20.224', None, 'No DNS record', None, False)
# Checking 10.10.20.225
# Found ('10.10.20.225', None, 'No DNS record', None, False)
# Checking 10.10.20.226
# Found ('10.10.20.226', None, 'No DNS record', None, False)
# Checking 10.10.20.227
# Found ('10.10.20.227', None, 'No DNS record', None, False)
# Checking 10.10.20.228
# Found ('10.10.20.228', None, 'No DNS record', None, False)
# Checking 10.10.20.229
# Found ('10.10.20.229', None, 'No DNS record', None, False)
# Checking 10.10.20.230
# Found ('10.10.20.230', None, 'No DNS record', None, False)
# Checking 10.10.20.231
# Found ('10.10.20.231', None, 'No DNS record', None, False)
# Checking 10.10.20.232
# Found ('10.10.20.232', None, 'No DNS record', None, False)
# Checking 10.10.20.233
# Found ('10.10.20.233', None, 'No DNS record', None, False)
# Checking 10.10.20.234
# Found ('10.10.20.234', None, 'No DNS record', None, False)
# Checking 10.10.20.235
# Found ('10.10.20.235', None, 'No DNS record', None, False)
# Checking 10.10.20.236
# Found ('10.10.20.236', None, 'No DNS record', None, False)
# Checking 10.10.20.237
# Found ('10.10.20.237', None, 'No DNS record', None, False)
# Checking 10.10.20.238
# Found ('10.10.20.238', None, 'No DNS record', None, False)
# Checking 10.10.20.239
# Found ('10.10.20.239', None, 'No DNS record', None, False)
# Checking 10.10.20.240
# Found ('10.10.20.240', None, 'No DNS record', None, False)
# Checking 10.10.20.241
# Found ('10.10.20.241', None, 'No DNS record', None, False)
# Checking 10.10.20.242
# Found ('10.10.20.242', None, 'No DNS record', None, False)
# Checking 10.10.20.243
# Found ('10.10.20.243', None, 'No DNS record', None, False)
# Checking 10.10.20.244
# Found ('10.10.20.244', None, 'No DNS record', None, False)
# Checking 10.10.20.245
# Found ('10.10.20.245', None, 'No DNS record', None, False)
# Checking 10.10.20.246
# Found ('10.10.20.246', None, 'No DNS record', None, False)
# Checking 10.10.20.247
# Found ('10.10.20.247', None, 'No DNS record', None, False)
# Checking 10.10.20.248
# Found ('10.10.20.248', None, 'No DNS record', None, False)
# Checking 10.10.20.249
# Found ('10.10.20.249', None, 'No DNS record', None, False)
# Checking 10.10.20.250
# Found ('10.10.20.250', None, 'No DNS record', None, False)
# Checking 10.10.20.251
# Found ('10.10.20.251', None, 'No DNS record', None, False)
# Checking 10.10.20.252
# Found ('10.10.20.252', None, 'No DNS record', None, False)
# Checking 10.10.20.253
# Found ('10.10.20.253', None, 'No DNS record', None, False)
# Checking 10.10.20.254
# Found ('10.10.20.254', None, 'No DNS record', None, False)
# Checking 10.10.20.255
# Found ('10.10.20.255', None, 'No DNS record', None, False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 31
#      28         print(f"Found {ip, mac, hostname, os_info, ssh_status}")
#      29         all_results[ip_range] = results
# ---> 31     create_excel_report(all_results, f'range_{ip_range}.xlsx')
#      32     print(f"Report generated as 'range_{ip_range}.xlsx'")
#      34 print("Scan Completed")
#
# Cell In[7], line 66, in create_excel_report(data, filename)
#      64 wb = openpyxl.Workbook()
#      65 for ip_range, results in data.items():
# ---> 66     ws = wb.create_sheet(title=ip_range)
#      67     ws.append(['IP', 'MAC Address', 'Hostname', 'OS','SSH'])
#      68     for result in results:
#      69         # Convert OS list to a string
#
# File ~/Programs/mambaforge/lib/python3.10/site-packages/openpyxl/workbook/workbook.py:199, in Workbook.create_sheet(self, title, index)
#     197     new_ws = WriteOnlyWorksheet(parent=self, title=title)
#     198 else:
# --> 199     new_ws = Worksheet(parent=self, title=title)
#     201 self._add_sheet(sheet=new_ws, index=index)
#     202 return new_ws
#
# File ~/Programs/mambaforge/lib/python3.10/site-packages/openpyxl/worksheet/worksheet.py:106, in Worksheet.__init__(self, parent, title)
#     105 def __init__(self, parent, title=None):
# --> 106     _WorkbookChild.__init__(self, parent, title)
#     107     self._setup()
#
# File ~/Programs/mambaforge/lib/python3.10/site-packages/openpyxl/workbook/child.py:47, in _WorkbookChild.__init__(self, parent, title)
#      45 def __init__(self, parent=None, title=None):
#      46     self._parent = parent
# ---> 47     self.title = title or self._default_title
#      48     self.HeaderFooter = HeaderFooter()
#
# File ~/Programs/mambaforge/lib/python3.10/site-packages/openpyxl/workbook/child.py:93, in _WorkbookChild.title(self, value)
#      91 if m:
#      92     msg = "Invalid character {0} found in sheet title".format(m.group(0))
# ---> 93     raise ValueError(msg)
#      95 if self.title is not None and self.title != value:
#      96     value = avoid_duplicate_name(self.parent.sheetnames, value)
#
# ValueError: Invalid character / found in sheet title

# %%
print(all_results)
# Out:
# {'1': [['194.117.20.192', None, 'net-lasige.di.fc.ul.pt', None, False], ['194.117.20.193', None, 'gw-lasige.di.fc.ul.pt', None, False], ['194.117.20.194', None, 'lxc-projecto-palvares-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.195', None, 'quinta.navigators.di.fc.ul.pt', None, True], ['194.117.20.196', None, 'lxc-projecto-gasaamoning-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.197', None, 'lxc-projecto-pmarques-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.198', None, 'lxc-projecto-bsousa-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.199', None, 'sato.lasige.di.fc.ul.pt', None, True], ['194.117.20.200', None, 'navs-karyon.lasige.di.fc.ul.pt', None, True], ['194.117.20.201', None, 'lasige-plone.lasige.di.fc.ul.pt', None, False], ['194.117.20.202', None, 'devobservatorio.di.fc.ul.pt', None, False], ['194.117.20.203', None, 'weblasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.204', None, 'forum2023.lasige.di.fc.ul.pt', None, True], ['194.117.20.205', None, 'lxc-projecto-alcides-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.206', None, 'No DNS record', None, True], ['194.117.20.207', None, 'lxc-projecto-xhan-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.208', None, 'hcimtemp.lasige.di.fc.ul.pt', None, False], ['194.117.20.209', None, 'projectos.lasige.di.fc.ul.pt', None, False], ['194.117.20.210', None, 'aquamon-lnec.lasige.di.fc.ul.pt', None, False], ['194.117.20.211', None, 'git.lasige.di.fc.ul.pt', None, True], ['194.117.20.212', None, 'lxc-projecto-asouto-complearn.lasige.di.fc.ul.pt', None, False], ['194.117.20.213', None, 'planetlab-pcu.di.fc.ul.pt', None, False], ['194.117.20.214', None, 'kvm2.lasige.di.fc.ul.pt', None, True], ['194.117.20.215', None, 'planetlab-2.di.fc.ul.pt', None, False], ['194.117.20.216', None, 'project-sato1.lasige.di.fc.ul.pt', None, True], ['194.117.20.217', None, 'No DNS record', None, False], ['194.117.20.218', None, 'No DNS record', None, True], ['194.117.20.219', None, 'keepsakebox.di.fc.ul.pt', None, False], ['194.117.20.220', None, 'duffyduck.di.fc.ul.pt', None, True], ['194.117.20.221', None, 'astarte.lasige.di.fc.ul.pt', None, True], ['194.117.20.222', None, 'lasige-inforum.lasige.di.fc.ul.pt', None, False], ['194.117.20.223', None, 'polaris.di.fc.ul.pt', None, False], ['194.117.20.224', None, 'ecoterra.ciencias.ulisboa.pt', None, False], ['194.117.20.225', None, 'web.lasige.di.fc.ul.pt', None, True], ['194.117.20.226', None, 'inforum2.di.fc.ul.pt', None, True], ['194.117.20.227', None, 'modest.lasige.di.fc.ul.pt', None, False], ['194.117.20.228', None, 'cloud.lasige.di.fc.ul.pt', None, True], ['194.117.20.229', None, 'project-sato2.lasige.di.fc.ul.pt', None, True], ['194.117.20.230', None, 'bdmy-01.lasige.di.fc.ul.pt', None, False], ['194.117.20.231', None, 'proliant-dl180.diogoferreira.pt', None, True], ['194.117.20.232', None, 'bdmy-03.lasige.di.fc.ul.pt', None, True], ['194.117.20.233', None, 'lxc-projecto-dmachado-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.234', None, 'bdmy-05.lasige.di.fc.ul.pt', None, False], ['194.117.20.235', None, 'janus.lasige.di.fc.ul.pt', None, False], ['194.117.20.236', None, 'bdmy-06.lasige.di.fc.ul.pt', None, False], ['194.117.20.237', None, 'mlvp.lasige.di.fc.ul.pt', None, False], ['194.117.20.238', None, 'lxc-projecto-anfalcao-lasige.lasige.di.fc.ul.pt', None, False], ['194.117.20.239', None, 'No DNS record', None, False], ['194.117.20.240', None, 'awesome-project.lasige.di.fc.ul.pt', None, False], ['194.117.20.241', None, 'No DNS record', None, True], ['194.117.20.242', None, 'lasige-temp37.di.fc.ul.pt', None, True], ['194.117.20.243', None, 'accessible-serv.di.fc.ul.pt', None, True], ['194.117.20.244', None, 'web-directive.eu', None, True], ['194.117.20.245', None, 'w5.di.fc.ul.pt', None, True], ['194.117.20.246', None, 'w4all.di.fc.ul.pt', None, False], ['194.117.20.247', None, 'w7.di.fc.ul.pt', None, False], ['194.117.20.248', None, 'w8.di.fc.ul.pt', None, False], ['194.117.20. ...
